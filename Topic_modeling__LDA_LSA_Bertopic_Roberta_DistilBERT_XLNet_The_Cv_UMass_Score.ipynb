# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
hotel = pd.read_csv('/content/drive/MyDrive/NLP WORK/Hotel_detail_final.txt', sep='\t')

# %%
# Reading the CSV file
review = pd.read_csv('/content/drive/MyDrive/NLP WORK/City_Hotel_reviews_all_final.txt', sep='\t')
# Out:
# <ipython-input-5-580d82b14e91>:2: DtypeWarning: Columns (11,16,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   review = pd.read_csv('/content/drive/MyDrive/NLP WORK/City_Hotel_reviews_all_final.txt', sep='\t')

# %%
review.rename(columns = {"Review's Hotel No.":"Hotel No."}, inplace = True)

# %%
final_df =pd.merge(review, hotel, on='Hotel No.', how='inner')

# %%
final_df.head(1)
# Out:
#    Review No. Reviewer                         Reviewer Profile Link  \
# 0       65565   Jeff F  https://www.tripadvisor.com/Profile/JeffF437
#
#   Review Title                                             Review  \
# 0         Just  Sort of worn a bit,. Devil is in the details, ...
#
#    Overall Rating_x  Aspect(Value)  Aspect(Location)  Aspect(Rooms)  \
# 0               4.0            3.0               4.0            3.0
#
#    Aspect(Service)  ...  Value Rating  \
# 0              4.0  ...           3.6
#
#                                   Property amenities  \
# 0  Valet parking // Wifi // Fitness Center with G...
#
#                                        Room features  \
# 0  Bathrobes // Air conditioning // Desk // Inter...
#
#                     Room types Good to know (Hotel Class)  \
# 0  Non-smoking rooms // Suites                        4.0
#
#    Good to know (Hotel Style) Walker's grade # of restaurants within .3 miles  \
# ...

# %%
# !pip install bertopic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 56.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 78.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 78.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# for DistilBERT

# %%
# !pip install transformers
import numpy as np
import pandas as pd
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %% [markdown]
# for XLNet

# %%
from tqdm import tqdm
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import re
import string

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import LsiModel
from gensim.models.coherencemodel import CoherenceModel

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
import nltk
from nltk.tokenize import word_tokenize

import torch
print(torch.__version__)
# Out:
# 2.0.1+cu118

# %%
# !pip install flair
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 65.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 57.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 62.6 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 45.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 37.6 MB/s eta 0:00:00
# ...

# %%
from flair.embeddings import FlairEmbeddings, DocumentPoolEmbeddings, BertEmbeddings, XLNetEmbeddings

# %%
from flair.data import Sentence

# %%
flair_embedding_forward = FlairEmbeddings("news-forward")
flair_embedding_backward = FlairEmbeddings("news-backward")
# Out:
# 2023-08-05 08:03:01,910 https://flair.informatik.hu-berlin.de/resources/embeddings/flair/news-forward-0.4.1.pt not found in cache, downloading to /tmp/tmpp36ah19f
# 100%|██████████| 69.7M/69.7M [00:05<00:00, 13.1MB/s]
# 2023-08-05 08:03:08,168 copying /tmp/tmpp36ah19f to cache at /root/.flair/embeddings/news-forward-0.4.1.pt
# 2023-08-05 08:03:08,263 removing temp file /tmp/tmpp36ah19f
# 2023-08-05 08:03:22,523 https://flair.informatik.hu-berlin.de/resources/embeddings/flair/news-backward-0.4.1.pt not found in cache, downloading to /tmp/tmpoci5hxzd
# 100%|██████████| 69.7M/69.7M [00:05<00:00, 12.6MB/s]
# 2023-08-05 08:03:29,017 copying /tmp/tmpoci5hxzd to cache at /root/.flair/embeddings/news-backward-0.4.1.pt
# 2023-08-05 08:03:29,288 removing temp file /tmp/tmpoci5hxzd

# %%
document_embeddings = DocumentPoolEmbeddings([ flair_embedding_backward, flair_embedding_forward])

# %%
# !pip install gensim

# %%
# !pip install scikit-learn

# %%
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
from gensim.models import LdaModel

# %%
import gensim
from gensim import corpora
from pprint import pprint

# %%
from gensim.models import LsiModel
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
from bertopic import BERTopic
from gensim.models import CoherenceModel

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# Pre-processing with NLTK
import nltk
from nltk.tokenize import word_tokenize
import re
from nltk.corpus import stopwords
from textblob import TextBlob
from nltk import pos_tag
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize,pos_tag


def pre_processing(text):

    # Lowercasing
    text_lower = text.lower()
    # Remove all non-alphanumeric characters from string, preserving whitespace
    text_clean = re.sub(r'[^\w\s]', '', text_lower)
    # Tokenize
    tokens = word_tokenize(text_clean)
    # Stop words Removal
    en_stopwords = stopwords.words('english')
    tokens_stopwords_removal = [token for token in tokens if token not in en_stopwords]
    #Lemmatization
    wordnet = WordNetLemmatizer()

    tokens_lemma =[]
    for token, tag in pos_tag(tokens_stopwords_removal):
        pos = tag[0].lower()
        if pos in ['a', 'r', 'n', 'v']:
            pos = pos
        else:
            pos ='n'
        tokens_lemma.append(wordnet.lemmatize(token,pos))

    # Remove extra stop words after lemmatization (hotel and room)

    tokens_extra_sw_removal = [token for token in tokens_lemma if token not in ["hotel"]]

    # SpellChecking using TextBlob
    text_spellchecked = str(TextBlob(' '.join(tokens_extra_sw_removal)).correct())


    return(text_spellchecked)

# %% [markdown]
# # ALL

# %%
data = final_df[:200]

# %%
preprocessed_reviews_nltk = [pre_processing(review) for review in data['Review']]

# %%
log_cols=["Metrics/Algorithm", "C_V","U_Mass"]
log = pd.DataFrame(columns=log_cols)
log
# Out:
# Empty DataFrame
# Columns: [Metrics/Algorithm, C_V, U_Mass]
# Index: []

# %% [markdown]
# ### LdaModel

# %%
# Tokenize the documents
tokenized_docs = [doc.lower().split() for doc in preprocessed_reviews_nltk]

# Create a dictionary from the tokenized documents
dictionary = corpora.Dictionary(tokenized_docs)

# Convert the tokenized documents into a bag-of-words representation
corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

# Train the LDA model
lda_model = gensim.models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, passes=5)

# Print the topics and their top words
pprint(lda_model.print_topics())
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# [(0,
#   '0.027*"room" + 0.020*"street" + 0.018*"belle" + 0.013*"great" + '
#   '0.013*"stay" + 0.010*"west" + 0.008*"night" + 0.008*"location" + '
#   '0.007*"nice" + 0.007*"clean"'),
#  (1,
#   '0.025*"room" + 0.013*"stay" + 0.011*"belle" + 0.011*"one" + 0.009*"street" '
#   '+ 0.008*"west" + 0.008*"time" + 0.008*"service" + 0.007*"get" + '
#   '0.007*"staff"'),
#  (2,
#   '0.021*"room" + 0.012*"stay" + 0.010*"nice" + 0.010*"west" + 0.010*"would" + '
#   '0.008*"location" + 0.007*"belle" + 0.006*"go" + 0.006*"get" + '
#   '0.006*"great"'),
#  (3,
#   '0.019*"stay" + 0.018*"room" + 0.015*"great" + 0.012*"staff" + '
#   '0.012*"memphis" + 0.010*"west" + 0.010*"belle" + 0.009*"street" + '
#   '0.009*"go" + 0.009*"location"'),
#  (4,
#   '0.023*"room" + 0.012*"stay" + 0.009*"belle" + 0.009*"park" + 0.008*"night" '
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import TruncatedSVD
from bertopic import BERTopic

# %%
vectorizer = CountVectorizer(stop_words="english")
X = vectorizer.fit_transform(preprocessed_reviews_nltk)

# %%
# Create the bag-of-words representation of the corpus
bow_corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

# Train an LDA model
num_topics = 5
lda_model = LdaModel(bow_corpus, num_topics=num_topics, id2word=dictionary)

# Compute the coherence score using the 'C_V' metric
coherence_model_cv = CoherenceModel(model=lda_model, texts=tokenized_docs, dictionary=dictionary, coherence='c_v')
cv_score = coherence_model_cv.get_coherence()

print("C_V Score:", cv_score)
# Compute the coherence score using the 'U_Mass' metric
coherence_model_umass = CoherenceModel(model=lda_model, texts=tokenized_docs, dictionary=lda_model.id2word, coherence='u_mass')
umass_score = coherence_model_umass.get_coherence()

print("U_Mass Score:", umass_score)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# C_V Score: 0.256202973755716
# U_Mass Score: -1.013023186803185

# %%
name = "LDA"
log_entry = pd.DataFrame([[name, cv_score,umass_score]], columns=log_cols)
log = log.append(log_entry)
log
# Out:
#   Metrics/Algorithm       C_V    U_Mass
# 0               LDA  0.256203 -1.013023

# %% [markdown]
# ### LSA model

# %%
documents =preprocessed_reviews_nltk
# Convert the documents into a matrix of TF-IDF features
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

# Apply LSA
lsa_model = TruncatedSVD(n_components=5)
lsa_matrix = lsa_model.fit_transform(tfidf_matrix)

# Display the topics

terms = vectorizer.get_feature_names_out ()
for i, component in enumerate(lsa_model.components_):
    topic_terms = " ".join([terms[ind] for ind in component.argsort()[:-5:-1]])
    print(f"Topic {i+1}: {topic_terms}")
# Out:
# Topic 1: room stay great street
# Topic 2: great street gibson guitar
# Topic 3: staff friendly great stay
# Topic 4: museum stay memphis soul
# Topic 5: great park downtown restaurant

# %%
# Tokenize the corpus into a list of lists of words
tokenized_corpus = [document.lower().split() for document in preprocessed_reviews_nltk]

# Create a dictionary from the tokenized corpus
dictionary = Dictionary(tokenized_corpus)
# Train the LSA model
lsa_model = LsiModel(bow_corpus, id2word=dictionary, num_topics=10)  # Adjust the number of topics as needed

# Compute the coherence score using the 'C_V' metric
coherence_model_cv = CoherenceModel(model=lsa_model, texts=tokenized_corpus, dictionary=dictionary, coherence='c_v')
cv_score = coherence_model_cv.get_coherence()

print("C_V Score:", cv_score)
# Compute the coherence score using the 'U_Mass' metric
coherence_model_umass = CoherenceModel(model=lsa_model, texts=tokenized_docs, dictionary=lsa_model.id2word, coherence='u_mass')
umass_score = coherence_model_umass.get_coherence()

print("U_Mass Score:", umass_score)
# Out:
# C_V Score: 0.35747235821255097
# U_Mass Score: -3.7958161292715715

# %%
name = "LSA"
log_entry = pd.DataFrame([[name, cv_score,umass_score]], columns=log_cols)
log = log.append(log_entry)
log
# Out:
#   Metrics/Algorithm       C_V    U_Mass
# 0               LDA  0.256203 -1.013023
# 0               LSA  0.357472 -3.795816

# %% [markdown]
# ### BERTopic

# %%
bertopic_model = BERTopic()
topics, probs = bertopic_model.fit_transform(preprocessed_reviews_nltk)
bertopic_model.visualize_barchart(top_n_topics=5)
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
bertopic_topic_words =bertopic_model.get_topic_info()
bertopic_topic_words
# Out:
#    Topic  Count                          Name  \
# 0     -1     63     -1_room_stay_street_belle
# 1      0     50         0_room_stay_would_one
# 2      1     37     1_memphis_great_stay_west
# 3      2     33  2_belle_room_street_location
# 4      3     17  3_gibson_guitar_belle_street
#
#                                       Representation  \
# 0  [room, stay, street, belle, west, go, get, sta...
# 1  [room, stay, would, one, get, charge, night, n...
# 2  [memphis, great, stay, west, room, location, b...
# 3  [belle, room, street, location, great, west, n...
# 4  [gibson, guitar, belle, street, stay, across, ...
#
#                                  Representative_Docs
# 0  [stay due great location close belle street gi...
# 1  [second time wife stay west complete disaster ...
# 2  [stay west memphis two night vacation septembe...
# 3  [can get better location west memphis belle st...
# 4  [west memphis belle street beautiful great loc...

# %%
# Initialize BERTopic and fit the corpus
tokenized_corpus = [document.lower().split() for document in preprocessed_reviews_nltk]


# Convert the topics to a list of word lists
word_lists = [[word for word, _ in bertopic_model.get_topic(topic)] for topic in topics]

# Create the dictionary from the topics
dictionary = corpora.Dictionary(word_lists)

# Create the bag-of-words representation of the corpus
bow_corpus = [dictionary.doc2bow(document) for document in tokenized_corpus]

# Compute the coherence score using the 'C_V' metric
coherence_model_cv = CoherenceModel(topics=word_lists, texts=tokenized_corpus, dictionary=dictionary, coherence='c_v')
cv_score = coherence_model_cv.get_coherence()

print("C_V Score:", cv_score)

# Compute the coherence score using the 'U_Mass' metric
coherence_model_umass = CoherenceModel(topics=word_lists, texts=tokenized_corpus, dictionary=dictionary, coherence='u_mass')
umass_score = coherence_model_umass.get_coherence()

print("U_Mass Score:", umass_score)
# Out:
# C_V Score: 0.42686994697013914
# U_Mass Score: -0.8639809003187523

# %%
name = "BERTopic"
log_entry = pd.DataFrame([[name, cv_score,umass_score]], columns=log_cols)
log = log.append(log_entry)
log
# Out:
#   Metrics/Algorithm       C_V    U_Mass
# 0               LDA  0.256203 -1.013023
# 0               LSA  0.357472 -3.795816
# 0          BERTopic  0.426870 -0.863981

# %% [markdown]
# # Roberta

# %%
robertamodel = BERTopic()

# %%
topics = robertamodel.fit(documents)

# %%
topics = robertamodel.transform(documents)

# %%
robertamodel.get_topic_info()
# Out:
#    Topic  Count                         Name  \
# 0     -1     42  -1_room_stay_street_memphis
# 1      0    109     0_room_stay_belle_street
# 2      1     32    1_memphis_great_stay_west
# 3      2     17   2_gibson_guitar_belle_stay
#
#                                       Representation  \
# 0  [room, stay, street, memphis, belle, location,...
# 1  [room, stay, belle, street, one, get, night, w...
# 2  [memphis, great, stay, west, location, room, w...
# 3  [gibson, guitar, belle, stay, street, great, a...
#
#                                  Representative_Docs
# 0  [return trip tennessee last 3 night memphis fi...
# 1  [second time wife stay west complete disaster ...
# 2  [stay west week moment arrive felt right staff...
# 3  [west memphis belle street beautiful great loc...

# %%
robertamodel.visualize_barchart(top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topics, probs = robertamodel.fit_transform(preprocessed_reviews_nltk)

# %%
# Initialize BERTopic and fit the corpus
tokenized_corpus = [document.lower().split() for document in preprocessed_reviews_nltk]

# Convert the topics to a list of word lists
word_lists = [[word for word, _ in robertamodel.get_topic(topic)] for topic in topics]

# Create the dictionary from the topics
dictionary = corpora.Dictionary(word_lists)

# Create the bag-of-words representation of the corpus
bow_corpus = [dictionary.doc2bow(document) for document in tokenized_corpus]

# Compute the coherence score using the 'C_V' metric
coherence_model_cv = CoherenceModel(topics=word_lists, texts=tokenized_corpus, dictionary=dictionary, coherence='c_v')
cv_score = coherence_model_cv.get_coherence()

print("C_V Score:", cv_score)

# Compute the coherence score using the 'U_Mass' metric
coherence_model_umass = CoherenceModel(topics=word_lists, texts=tokenized_corpus, dictionary=dictionary, coherence='u_mass')
umass_score = coherence_model_umass.get_coherence()

print("U_Mass Score:", umass_score)
# Out:
# C_V Score: 0.39379351831238407
# U_Mass Score: -0.7450557806586445

# %%
name = "Roberta"
log_entry = pd.DataFrame([[name, cv_score,umass_score]], columns=log_cols)
log = log.append(log_entry)
log
# Out:
#   Metrics/Algorithm       C_V    U_Mass
# 0               LDA  0.256203 -1.013023
# 0               LSA  0.357472 -3.795816
# 0          BERTopic  0.426870 -0.863981
# 0           Roberta  0.393794 -0.745056

# %% [markdown]
# # DistilBERT

# %%
# Step 1: Tokenization using DistilBERT tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
tokenized_texts = [tokenizer.tokenize(document) for document in documents]

# Step 2: Obtain embeddings using DistilBERT model
model = DistilBertModel.from_pretrained('distilbert-base-uncased')

# %%
# Step 3: Apply CountVectorizer to obtain document-topic matrix
vectorizer = CountVectorizer(max_features=10_000, stop_words='english')
X = vectorizer.fit_transform([" ".join(tokens) for tokens in tokenized_texts])

# Step 4: Apply Latent Dirichlet Allocation (LDA) for topic modeling
num_topics = 5  # Number of topics to discover
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
document_topics = lda.fit_transform(X)

# Display the topics
feature_names = vectorizer.get_feature_names_out()
topic_words = {}

for topic_idx, topic in enumerate(lda.components_):
    top_indices = topic.argsort()[-5:][::-1]  # Top 5 words in each topic
    topic_words[topic_idx] = [feature_names[i] for i in top_indices]

for topic_idx, words in topic_words.items():
    print(f"Topic {topic_idx + 1}: {' '.join(words)}")
# Out:
# Topic 1: room stay great staff west
# Topic 2: room stay west belle great
# Topic 3: room street belle nice location
# Topic 4: room stay belle street night
# Topic 5: room staff location stay belle

# %%
# Create the bag-of-words representation of the corpus
bow_corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

# Train an LDA model
num_topics = 5
lda_model = LdaModel(bow_corpus, num_topics=num_topics, id2word=dictionary)

# Compute the coherence score using the 'C_V' metric
coherence_model_cv = CoherenceModel(model=lda_model, texts=tokenized_docs, dictionary=dictionary, coherence='c_v')
cv_score = coherence_model_cv.get_coherence()

print("C_V Score:", cv_score)
# Compute the coherence score using the 'U_Mass' metric
coherence_model_umass = CoherenceModel(model=lda_model, texts=tokenized_docs, dictionary=lda_model.id2word, coherence='u_mass')
umass_score = coherence_model_umass.get_coherence()

print("U_Mass Score:", umass_score)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# C_V Score: 0.3171467217877697
# U_Mass Score: -0.9938564202634765

# %%
name = "DistilBERT"
log_entry = pd.DataFrame([[name, cv_score,umass_score]], columns=log_cols)
log = log.append(log_entry)
log
# Out:
#   Metrics/Algorithm       C_V    U_Mass
# 0               LDA  0.256203 -1.013023
# 0               LSA  0.357472 -3.795816
# 0          BERTopic  0.426870 -0.863981
# 0           Roberta  0.393794 -0.745056
# 0        DistilBERT  0.317147 -0.993856

# %% [markdown]
# # XLNet

# %%
df1 = final_df.loc[:, [ 'Review']]

# %%
df = df1[500:700]

# %%
documents = df['Review'].values.tolist()

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_data(doc_set):

    texts = []
    for i in doc_set:

        #Lowercase
        input_str = i.lower()

        #Remove numbers
        input_str_1 = re.sub(r'\d+', '', input_str)

        #Remove Punctuation
        #input_str_2 = input_str_1.translate(str.maketrans('', '', string.punctuation))
        input_str_2 = re.sub('[^a-zA-Z0-9]{3,}', ' ', input_str_1)
        input_str_2 = re.sub('\[.*?\]', '', input_str_2)
        input_str_2 = re.sub('[%s]' % re.escape(string.punctuation), '', input_str_2)
        input_str_2 = re.sub('\w*\d\w*', '', input_str_2)
        input_str_2 = re.sub('[‘’“”…]', '', input_str_2)
        input_str_2 = re.sub('\n', '', input_str_2)

        #Remove stopwords
        word_tokens = word_tokenize(input_str_2)
        input_str_3 = [word for word in word_tokens if word not in stop_words]

        #Lemmatize
        input_str_4 = [lemmatizer.lemmatize(word, pos ='v') for word in input_str_3]

        output = (' '.join(input_str_4))

        texts.append(output)
        #return(input_str_2)

    return(texts)

# %%
clean_text=preprocess_data(documents)

# %%
df['Review_clean'] = clean_text

# %%
df.head()
# Out:
#                                                 Review  \
# 500  We booked 2 nights at the La Quinta, and we kn...
# 501  We had a great vacation at LaQuinta. The staff...
# 502  Disgustingly dirty hotel! Rude staff! If I cou...
# 503  DO NOT STAY at this property under any circums...
# 504  I understand the world is crazy and it's hard ...
#
#                                           Review_clean
# 500  book nights la quinta know get pay extent howe...
# 501  great vacation laquinta staff especially mill ...
# 502  disgustingly dirty hotel rude staff could rate...
# 503  stay property circumstances filthy top bottom ...
# 504  understand world crazy hard find good help rid...

# %%
X = torch.empty(size=(len(df.index), 6144)).cuda()

# %%
type(document_embeddings)
# Out:
# flair.embeddings.document.DocumentPoolEmbeddings

# %%
X = X.cpu().detach().numpy()
X_red = X

# %%
N_CLUSTERS = 6

kmeans = KMeans()
kmeans.fit(X_red)
pred = kmeans.fit_predict(X_red)

# %%
df['new_topic_km'] = pred

# %%
def get_top_words(documents, top_n):
  '''
  function to get top tf-idf words and phrases
  '''
  vectoriser = TfidfVectorizer(ngram_range=(1, 2),
                               max_df=0.5)
  tfidf_matrix = vectoriser.fit_transform(documents)
  feature_names = vectoriser.get_feature_names_out()
  df_tfidf = pd.DataFrame()
  for doc in range(len(documents)):
    words = []
    scores = []
    feature_index = tfidf_matrix[doc,:].nonzero()[1]
    tfidf_scores = zip(feature_index, [tfidf_matrix[doc, x] for x in feature_index])
    for w, s in [(feature_names[i], s) for (i, s) in tfidf_scores]:
      words.append(w)
      scores.append(s)
    df_temp = pd.DataFrame(data={'word':words, 'score':scores})
    df_temp = df_temp.sort_values('score',ascending=False).head(top_n)
    df_temp['topic'] = doc
    df_tfidf = df_tfidf.append(df_temp)
  return df_tfidf

# %%
topic_docs = []
# group text into topic-documents
for topic in range(N_CLUSTERS):
    topic_docs.append(' '.join(df[df['new_topic_km']==topic]['Review_clean'].values))

# %%
df_tfidf = get_top_words(topic_docs, 10)

# %%
df_tfidf
# Out:
#            word     score  topic
# 9525       room  0.435534      0
# 9522       stay  0.331927      0
# 9508      hotel  0.303147      0
# 9429      staff  0.193784      0
# 9502      clean  0.165004      0
# 9470  breakfast  0.138143      0
# 9360       need  0.130468      0
# 9260       like  0.122794      0
# 9529        get  0.120875      0
# 9449      great  0.117038      0

# %%
xLNetmodel = BERTopic()
topics, probs = xLNetmodel.fit_transform(preprocessed_reviews_nltk)

# Initialize BERTopic and fit the corpus
tokenized_corpus = [document.lower().split() for document in preprocessed_reviews_nltk]


# Convert the topics to a list of word lists
word_lists = [[word for word, _ in xLNetmodel.get_topic(topic)] for topic in topics]

# Create the dictionary from the topics
dictionary = corpora.Dictionary(word_lists)

# Create the bag-of-words representation of the corpus
bow_corpus = [dictionary.doc2bow(document) for document in tokenized_corpus]

# Compute the coherence score using the 'C_V' metric
coherence_model_cv = CoherenceModel(topics=word_lists, texts=tokenized_corpus, dictionary=dictionary, coherence='c_v')
cv_score = coherence_model_cv.get_coherence()

print("C_V Score:", cv_score)

# Compute the coherence score using the 'U_Mass' metric
coherence_model_umass = CoherenceModel(topics=word_lists, texts=tokenized_corpus, dictionary=dictionary, coherence='u_mass')
umass_score = coherence_model_umass.get_coherence()

print("U_Mass Score:", umass_score)
# Out:
# C_V Score: 0.4422694501295368
# U_Mass Score: -0.8499027794557732

# %%
name = "XLNet "
log_entry = pd.DataFrame([[name, cv_score,umass_score]], columns=log_cols)
log = log.append(log_entry)
log
# Out:
#   Metrics/Algorithm       C_V    U_Mass
# 0               LDA  0.256203 -1.013023
# 0               LSA  0.357472 -3.795816
# 0          BERTopic  0.426870 -0.863981
# 0           Roberta  0.393794 -0.745056
# 0        DistilBERT  0.317147 -0.993856
# 0            XLNet   0.442269 -0.849903

# %% [markdown]
# ## Compare

# %%
vectorizer = CountVectorizer(stop_words="english")
X = vectorizer.fit_transform(preprocessed_reviews_nltk)

# %%
# LDA
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)
lda_topics = lda.transform(X)
lda_topic_words = np.array(vectorizer.get_feature_names_out())[np.argsort(lda.components_)[:, ::-1][:, :5]]

# LSA
lsa = TruncatedSVD(n_components=5, random_state=42)
lsa.fit(X)
lsa_topics = lsa.transform(X)
lsa_topic_words = np.array(vectorizer.get_feature_names_out())[np.argsort(lsa.components_)[:, ::-1][:, :5]]

# %%
arrays = []
n = 0
for index, row in bertopic_topic_words.iterrows():
    my_array = np.array(row['Representation'])
    new_array = arrays.append(my_array)
    if n == 5:
      break


    # print(row['Representation'])
    # print(type(row['Representation']))

arrays
# Out:
# [array(['room', 'stay', 'street', 'belle', 'west', 'go', 'get', 'staff',
#         'day', 'location'], dtype='<U8'),
#  array(['room', 'stay', 'would', 'one', 'get', 'charge', 'night', 'nice',
#         'front', 'desk'], dtype='<U6'),
#  array(['memphis', 'great', 'stay', 'west', 'room', 'location', 'belle',
#         'restaurant', 'place', 'staff'], dtype='<U10'),
#  array(['belle', 'room', 'street', 'location', 'great', 'west', 'night',
#         'one', 'nice', 'stay'], dtype='<U8'),
#  array(['gibson', 'guitar', 'belle', 'street', 'stay', 'across', 'great',
#         'west', 'factory', 'museum'], dtype='<U7')]

# %%
# Create a table to compare topics
topic_table = pd.DataFrame(columns=['LDA', 'LSA', 'BERTopic'])

# %%
# Add LDA topics to the table
for i, topic_words in enumerate(lda_topic_words):
    topic_table.at[f"Topic {i+1}", 'LDA'] = ', '.join(topic_words)

# %%
# Add LSA topics to the table
for i, topic_words in enumerate(lsa_topic_words):
    topic_table.at[f"Topic {i+1}", 'LSA'] = ', '.join(topic_words)

# %%
# Add LDA topics to the table
for i, topic_words in enumerate(arrays):
    # topic_table.loc[f"Topic {i+1}"] = [', '.join(topic_words), '', '']

    topic_table.at[f"Topic {i+1}", 'BERTopic'] = ', '.join(topic_words)

# %%
# Add LDA topics to the table

# %%
log
# Out:
#   Metrics/Algorithm       C_V    U_Mass
# 0               LDA  0.256203 -1.013023
# 0               LSA  0.357472 -3.795816
# 0          BERTopic  0.426870 -0.863981
# 0           Roberta  0.393794 -0.745056
# 0        DistilBERT  0.317147 -0.993856
# 0            XLNet   0.442269 -0.849903

# %%
topic_table
# Out:
#                                          LDA  \
# Topic 1  room, belle, street, service, great
# Topic 2  room, stay, belle, location, street
# Topic 3     room, stay, street, great, belle
# Topic 4         room, nice, west, stay, good
# Topic 5         room, clean, park, fee, west
#
#                                          LSA  \
# Topic 1     room, stay, belle, street, great
# Topic 2   room, check, ready, book, handicap
# Topic 3       stay, night, west, time, point
# Topic 4  west, service, check, staff, lawton
# Topic 5       great, walk, desk, staff, stay
#
#                                                   BERTopic
# Topic 1  room, stay, street, belle, west, go, get, staf...
# Topic 2  room, stay, would, one, get, charge, night, ni...
# Topic 3  memphis, great, stay, west, room, location, be...
# Topic 4  belle, room, street, location, great, west, ni...
# Topic 5  gibson, guitar, belle, street, stay, across, g...
